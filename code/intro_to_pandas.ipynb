# %% [markdown]
# # Intro to Pandas
# Pandas is a Python module used for working with data formatted as a table. You can use it to analyze large datasets- and it offers more flexibility than Excel when it comes to data cleaning.
#
# Today we'll use Pandas to explore and visualize employee attrition data. After this session, you'll be able to:
# - Create a DataFrame from a file
# - Understand the different components of a DataFrame
# - Inspect your data and calculate summary statistics
# - Subset Data
# - Clean and visualize your data

# %% [markdown]
# ## Creating DataFrames
# Today we're going to reading data in from a [csv file](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html). But, there are many ways to create DataFrames in Pandas. Including reading data from [excel files](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html), [sql tables](https://pandas.pydata.org/docs/reference/api/pandas.read_sql_table.html), and even [html](https://pandas.pydata.org/docs/reference/api/pandas.read_html.html).

# %%
import pandas as pd # import loads the pandas library and the naming convetion is to call pandas as pd

# reads the csv file into the employees DataFrame
employees = pd.read_csv(r'C:\Users\nmatt\python_scripts\python_for_excel_users\data\input'
                        '\WA_Fn-UseC_-HR-Employee-Attrition.csv') #the string is the file location and name
employees
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## Pandas Data Structures vs Excel Tables
#
# As you can see below, a Pandas DataFrame looks very similar to an Excel table or worksheet. Like Excel tables, pandas DataFrames are made up of columns, rows and indices. However, in Pandas, a column is called a series and row indices begin with 0 instead of 1.
#
#
# #### Excel
#
# ![image.png](attachment:image.png)
#
#
# #### DataFrame
#
# |    |   Age | Attrition   | BusinessTravel    |   DailyRate | Department             |
# |---:|------:|:------------|:------------------|------------:|:-----------------------|
# |  0 |    41 | Yes         | Travel_Rarely     |        1102 | Sales                  |
# |  1 |    49 | No          | Travel_Frequently |         279 | Research & Development |
# |  2 |    37 | Yes         | Travel_Rarely     |        1373 | Research & Development |
# |  3 |    33 | No          | Travel_Frequently |        1392 | Research & Development |
# |  4 |    27 | No          | Travel_Rarely     |         591 | Research & Development |

# %% [markdown]
# ### Index
#
# An index is a row label and can be used to select data. Pandas indices can be text or numeric. A numeric index will show as a range index. But a string index will show as an Index and provide the values as a list

# %%
employees.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %% [markdown]
# ### Columns
#
# The columns attribute gives you a list of the column names

# %%
employees.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Exploring Your DataFrame
#
# Aside, from the columns and indices, there are many other attributes and methods you can use to learn about your data.

# %% [markdown]
# ### Shape
#
# The shape attribute tells you how many rows and columns the DataFrame has

# %%
employees.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Info Method
#
# The info method gives you the number of rows, a list of columns, the count of non-null fields, and the data type (Dtype).
#
# #### Non-null values
# Non-null simply means there's a valid value in a cell. It's important to find and address missing or null values before reshaping or performing any calculations on your DataFrame.
#
#
# #### Pandas DataTypes
# DataTypes are a way of classifying the type of information that a variable holds. The ways that you can manipulate the data is dependent on the type of DataType you use. We'll touch on this more in depth when we start cleaning our data.
#
#
# |  Pandas DataType  |   Description |
# |:---:|:------:|
# |  object |    string - text |
# |  int64 |    integer numbers |
# |  float64 |    floating point numbers |
# |  bool |    True/False values |
# |  datetime64 |    Date and Time values |
# |  timedelta[ns] |    Difference between datetimes |
# |  category |    Categorical data like Department |

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Finding null values in your DataFrame
#
# You can use the isna() function to find null values in your DataFrame. Just calling the method will return a True or False in each cell.
#
# ```python
#
# employees.isna()
#
# ```
#
#
# |    |   Age |   Attrition |   BusinessTravel |   DailyRate |   Department |
# |---:|------:|------------:|-----------------:|------------:|-------------:|
# |  0 |     False |           False |                False |           False |            False |
# |  1 |     False |           False |                False |           False |            False |
# |  2 |     False |           False |                False |           False |            False |
# |  3 |     False |           False |                False |           False |            False |
# |  4 |     False |           False |                False |           False |            False
#
#
# Doesn't seem too helpful. But, in Python True is equivalent to 1 and False is equivalent to 0 which means you can actually total these values up to get a count of NaN or null values in each column
#
#
# ##### Method Chaining
#
# A nice feature of Pandas is that you can do what's called method chaining
#
# ``` python
# # uses .isna() to identify NA cells
# # uses .sum() to total the sum of NaN cells
# employees.isna().sum()
#
#
# ```

# %%
employees.isna()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
# gets a count of cells that have null values
employees.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Visually Inspecting Your Data
#
# After reading in your file in there are a few methods that you can use to confirm that your data loaded correctly
#
# ```python
#
# # Head
# employees.head() # shows the first 5 rows of the data
#
# # Tail
# employees.tail() # shows the last 5 rows of the data
#
# # Sample
# employees.sample(5) # pass an integer to this method to get a random sample of the data; # this will return 5 rows
#
#
# ```

# %%
# shows the first 5 rows of the data
employees.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# shows the last 5 rows of the data
employees.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
# pass an integer to this method to get a random 
# sample of the data; # this will return 5 rows
employees.sample(5)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 655    33        No  Travel_Rarely       1075         Human Resources
# 1230   24        No  Travel_Rarely        506  Research & Development
# 305    36        No     Non-Travel       1105  Research & Development
# 1275   51        No  Travel_Rarely        942  Research & Development
# 1265   33        No     Non-Travel        775  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 655                  3          2   Human Resources              1
# 1230                29          1           Medical              1
# 305                 24          4     Life Sciences              1
# 1275                 3          3  Technical Degree              1
# 1265                 4          3  Technical Degree              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 655              910  ...                         3            80
# ...

# %% [markdown]
# ## Summary Statistics
#
# The describe method returns a DataFrame of descriptive statistics of all the numeric DateTypes in your DataFrame.

# %%
employees.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Including all in the describe() method gives some information about categorical variables but it isn't very informative.
# For example, if you look at the Department column, it will show you the most frequently occuring value and the number of occurences

# %%
employees.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# ### Individual Statistics
# You can also calculate statistics for numerical columns individually

# %%
# calculates the median value
employees.DailyRate.median()
# Out:
# 802.0

# %%
# calculates the max value
employees.DailyRate.max()
# Out:
# 1499

# %%
# calculates the min value
employees.DailyRate.min()
# Out:
# 102

# %%
# calculates the mode 
# the most frequently occuring value
employees.DailyRate.mode()
# Out:
# 0    691
# dtype: int64

# %%
# calculates the standard deviation
employees.DailyRate.std()
# Out:
# 403.50909994352827

# %% [markdown]
# ### Value Counts
#
# The .value_counts() method of a series is a more useful way of looking at your categorical data. It provides counts of the unique values in the column.
#
# ``` python
# employees.Department.value_counts()
#
# ```
# |                        |   Department |
# |:-----------------------|-------------:|
# | Research & Development |          961 |
# | Sales                  |          446 |
# | Human Resources        |           63 |
#
# NaN or missing values won't be included in the count. If you'd like to include them you need to pass dropna = False to the value_counts() function
#
# ```python
# employees.Department.value_counts(dropna = False)
#
# ```
#
# #### normalize
#
# The value_counts() function can also return the values as a percentage of the total when you use the normalize = True parameter
#
# ```python
# employees.Department.value_counts(dropna = False, normalize = True)
#
# ```
#
# |                        |   Department |
# |:-----------------------|-------------:|
# | Research & Development |    0.653741  |
# | Sales                  |    0.303401  |
# | Human Resources        |    0.0428571 |

# %%
# returns the counts of the unique values in the series
employees.Department.value_counts(dropna = False)
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
# returns the values as a percentage of the total
employees.Department.value_counts(dropna = False, normalize = True)
# Out:
# Research & Development    0.653741
# Sales                     0.303401
# Human Resources           0.042857
# Name: Department, dtype: float64

# %% [markdown]
# ### Unique Counts
#
# nunique() gives the number of unique values in a series
#
# unique() gives a list of the unique values in a series

# %%
# the number of unique categorical values
employees.JobRole.nunique()
# Out:
# 9

# %%
# returns a list of unique values
employees.JobRole.unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %% [markdown]
# ## Selecting Data
#
# One of the advantages of working with Pandas is that it's easy to subset data to find the specific information that you're looking for.  Let's start by selecting columns.

# %% [markdown]
# ### Selecting Columns
#
# There are two ways to select a column from a Pandas DataFrame. You can use either bracket notation or what's referred to as dot notation. There are certain times that you HAVE TO use bracket notation.
#
# #### When to Use Bracket Notation
# 1. when column name includes a space
#
# ```python
# # selects only the first name column
# employees['first name']
# ```
#
# 2. column name matches a pandas DataFrame method
#
# ```python
# employees['count']
# ```
#
# 3. column name matches a restricted python word. See the link for the [full list](https://docs.python.org/2.5/ref/keywords.html)
#
#
# ```python
# employees['count']
# ```
#
# 4. column name is stored in a variable
#
# ```python
#
# dept = 'Department'
#
# employees[dept]
# ```
#
# 5. column name is in an integer
#
# ```python
# employees[0]
# ```
# 6. when creating a new column
#
# ```python
# employees['status'] = 'active'
# ```
# 7. when selecting multiple columns
#
# ```python
# # example of a python list
# # ['Attrition', 'Department']
#
# # selecting the Attrition and Department columns from the employees DataFrame
# employees[['Attrition', 'Department']]
#
#
# ```
#
# #### Dot Notation
# If none of the conditions above are met then you can use dot notation to treat the column name as an attribute of a DataFrame. In coding, an attribute gives you a piece of information about an object. Throught this session we'll use attributes to give you
# more information about your data
#
# ```python
#
# # shows the column feature employee age
# employees.Age
# ```

# %%
# shows the column feature employee age
employees.Age
# Out:
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %% [markdown]
# ### Selecting multiple columns
#
# You can also use bracket notation to select multiple columns. In python, a list is created using square brackets. We can select multiple columns by passing a list of column names to the brackets. This returns a DataFrame with the selected columns.
#
#
# ```python
#
# # example of a python list
# # ['Attrition', 'Department']
#
# # selecting the Attrition and Department columns from the employees DataFrame
# employees[['Attrition', 'Department']]
#
#
# ```

# %%
employees[['Attrition', 'Department']]
# Out:
#      Attrition              Department
# 0          Yes                   Sales
# 1           No  Research & Development
# 2          Yes  Research & Development
# 3           No  Research & Development
# 4           No  Research & Development
# ...        ...                     ...
# 1465        No  Research & Development
# 1466        No  Research & Development
# 1467        No  Research & Development
# 1468        No                   Sales
# 1469        No  Research & Development
#
# [1470 rows x 2 columns]

# %% [markdown]
# ### Selecting Rows by Index
#
#
# You can easily select rows by passing their index to the brackets
#
#
# ```python
# # returns rows up to but not including 60
# employees[50:60]
#
# # the notation below returns row 25 up to but not including 26
# employees[25:26]
#
# ```

# %%
# returns all rows from 50 on
employees[50:]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 50     48       Yes      Travel_Rarely        626  Research & Development
# 51     28       Yes      Travel_Rarely       1434  Research & Development
# 52     44        No      Travel_Rarely       1488                   Sales
# 53     35        No         Non-Travel       1097  Research & Development
# 54     26        No      Travel_Rarely       1443                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
# returns rows up to but not including 60
employees[50:60]
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 50   48       Yes      Travel_Rarely        626  Research & Development
# 51   28       Yes      Travel_Rarely       1434  Research & Development
# 52   44        No      Travel_Rarely       1488                   Sales
# 53   35        No         Non-Travel       1097  Research & Development
# 54   26        No      Travel_Rarely       1443                   Sales
# 55   33        No  Travel_Frequently        515  Research & Development
# 56   35        No  Travel_Frequently        853                   Sales
# 57   35        No      Travel_Rarely       1142  Research & Development
# 58   31        No      Travel_Rarely        655  Research & Development
# 59   37        No      Travel_Rarely       1115  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 50                 1          2     Life Sciences              1
# ...

# %%
# returns row 25 but excludes row 26
employees[25:26]
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 25   53        No  Travel_Rarely       1282  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 25                 5          3          Other              1              32
#
#     ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 25  ...                         4            80                 1
#
#     TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 25                 26                      3               2              14
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 25                 13                        4                     8
#
# [1 rows x 35 columns]

# %% [markdown]
# ### Boolean Indexing
#
# In the examples above, we filtered DataFrames based on their row or column labels. We can also filter DataFrames based on the cell value.  This is exactly the same as filtering data with Excel, but you'll find you have a lot more flexibility.
#
# Pandas uses Boolean Indexing to filter data. Essentially, you're telling it to find all the rows that meet a given condition.
# This is very similar to writing a conditional formula in Excel except you can filter all of your data with it.
#
#
#
# |  Logical Operators |   Description |
# |:---:|:------:|
# |  > |    greater than |
# |  < |    less than |
# |  == |    equal |
# |  != |    not equal |
# |  & |    and - when 2 or more conditions must be met |
# |  \||    or - when any conditions must be met |
# |  ~ |    not |
#
#
#
#
# For example, if you want to find all of the employees who work in the Sales Department you will need to:
# 1. Write the condition
# 2. Include the condition in your selection brackets
#
# If you run the condition by itself, it will return True or False to identify cells in the column that meet the condition
# ``` python
# # condition to return employees in the Sales department
# employees.Department == 'Sales'
#
# ```
#
# |    |   Department  |
# |---:|-----------------:|
# |  0 |                True |
# |  1 |                False |
# |  2 |                False |
# |  3 |                False |
# |  4 |                False |
#
# When you pass that condition to the bracket notation, it will return a subset of the original DataFrame where that condition is True
#
#
# ```python
# # returns a DataFrame of all employees in Sales
# employees[employees.Department == 'Sales']
# ```
#
# |    |   Age | Attrition   | BusinessTravel   |   DailyRate | Department   |   DistanceFromHome |   Education | EducationField   |   EmployeeCount |   EmployeeNumber |   EnvironmentSatisfaction | Gender   |   HourlyRate |   JobInvolvement |   JobLevel | JobRole              |   JobSatisfaction | MaritalStatus   |   MonthlyIncome |   MonthlyRate |   NumCompaniesWorked | Over18   | OverTime   |   PercentSalaryHike |   PerformanceRating |   RelationshipSatisfaction |   StandardHours |   StockOptionLevel |   TotalWorkingYears |   TrainingTimesLastYear |   WorkLifeBalance |   YearsAtCompany |   YearsInCurrentRole |   YearsSinceLastPromotion |   YearsWithCurrManager |
# |---:|------:|:------------|:-----------------|------------:|:-------------|-------------------:|------------:|:-----------------|----------------:|-----------------:|--------------------------:|:---------|-------------:|-----------------:|-----------:|:---------------------|------------------:|:----------------|----------------:|--------------:|---------------------:|:---------|:-----------|--------------------:|--------------------:|---------------------------:|----------------:|-------------------:|--------------------:|------------------------:|------------------:|-----------------:|---------------------:|--------------------------:|-----------------------:|
# |  0 |    41 | Yes         | Travel_Rarely    |        1102 | Sales        |                  1 |           2 | Life Sciences    |               1 |                1 |                         2 | Female   |           94 |                3 |          2 | Sales Executive      |                 4 | Single          |            5993 |         19479 |                    8 | Y        | Yes        |                  11 |                   3 |                          1 |              80 |                  0 |                   8 |                       0 |                 1 |                6 |                    4 |                         0 |                      5 |
# | 18 |    53 | No          | Travel_Rarely    |        1219 | Sales        |                  2 |           4 | Life Sciences    |               1 |               23 |                         1 | Female   |           78 |                2 |          4 | Manager              |                 4 | Married         |           15427 |         22021 |                    2 | Y        | No         |                  16 |                   3 |                          3 |              80 |                  0 |                  31 |                       3 |                 3 |               25 |                    8 |                         3 |                      7 |
# | 21 |    36 | Yes         | Travel_Rarely    |        1218 | Sales        |                  9 |           4 | Life Sciences    |               1 |               27 |                         3 | Male     |           82 |                2 |          1 | Sales Representative |                 1 | Single          |            3407 |          6986 |                    7 | Y        | No         |                  23 |                   4 |                          2 |              80 |                  0 |                  10 |                       4 |                 3 |                5 |                    3 |                         0 |                      3 |
# | 27 |    42 | No          | Travel_Rarely    |         691 | Sales        |                  8 |           4 | Marketing        |               1 |               35 |                         3 | Male     |           48 |                3 |          2 | Sales Executive      |                 2 | Married         |            6825 |         21173 |                    0 | Y        | No         |                  11 |                   3 |                          4 |              80 |                  1 |                  10 |                       2 |                 3 |                9 |                    7 |                         4 |                      2 |
# | 29 |    46 | No          | Travel_Rarely    |         705 | Sales        |                  2 |           4 | Marketing        |               1 |               38 |                         2 | Female   |           83 |                3 |          5 | Manager              |                 1 | Single          |           18947 |         22822 |                    3 | Y        | No         |                  12 |                   3 |                          4 |              80 |                  0 |                  22 |                       2 |                 2 |                2 |                    2 |                         2 |                      1 |
#
#
# #### Multiple Conditions
#
# You can also pass more than one condition to the selection brackets. Each condition gets wrapped in parentheses if you have more than one. Let's consider three examples of groups that we might want to search for:
# 1. Employees in the sales department with a job satisfaction greater than or equal to three
# 2. Employees in either Sales or Human Resources Departments
# 3. Employees in Sales who travel frequently
#
# ```python
# # returns employees in Sales with a JobSatisfaction score of 3 or more
# (employees.Department == 'Sales') & (employees.JobSatisfaction >= 3)
#
# # There are three departments in our dataset so there are two ways to get employees in Sales or HR
# # Method 1
# # use the bitwise or operator
# # returns employees in either the Sales Department or the Human Resources Department
# (employees.Department == 'Sales') | (employees.Department == 'Human Resources')
#
# # Method 2
# # use the bitwise not operator
# # returns employees not in Research & Development which is by default those in HR or Sales
# ~(employees.Department == 'Research & Development')
#
#
# # returns employees in Sales who travel frequently
# (employees.Department == 'Sales') & (employees.BusinessTravel == 'Travel_Frequently')
#
# ```
#
# Any of these results can be used to create a new DataFrame that you can use for additional analysis
#
# ``` python
# # create a DataFrame of Sales employees who are frequent travelers and store it in a new variable
# # note the use of the copy() function. without this changes made to the new DataFrame will also be reflected on the original
# frequent_travelers = employees[(employees.Department == 'Sales') & (employees.BusinessTravel == 'Travel_Frequently')].copy()
#
#
# ```

# %%
# condition to return employees in the Sales department
employees.Department == 'Sales'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468     True
# 1469    False
# Name: Department, Length: 1470, dtype: bool

# %%
# returns a DataFrame of all employees in Sales
employees[employees.Department == 'Sales']
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 18     53        No      Travel_Rarely       1219      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 27     42        No      Travel_Rarely        691      Sales
# 29     46        No      Travel_Rarely        705      Sales
# ...   ...       ...                ...        ...        ...
# 1454   45        No      Travel_Rarely        374      Sales
# 1461   50       Yes      Travel_Rarely        410      Sales
# 1462   39        No      Travel_Rarely        722      Sales
# 1464   26        No      Travel_Rarely       1167      Sales
# 1468   49        No  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 18                   2          4  Life Sciences              1
# ...

# %% [markdown]
# ### Advanced Filtering
#
# Bracket notation is great if you only need to filter rows but there might be situations where you want to filter both rows AND columns.  In those instances, you'll have to use either the .iloc or .loc operators. The .iloc operator uses the numeric row and column indices to filter data while .loc uses row and column labels.
#
# #### .iloc
#
# The DailyRate and Department columns are indices 3 and 4 respectively. I would use the syntax below to pull rows 10 through 15 of the DataFrame
#
# ```python
# # returns rows 10 up to but not including 16 and columns 3 up to but not including 5
# # the colon indicates you want to select a range of values
# employees.iloc[10:16, 3:5]
#
# # alternatively you can pass the column indices to the selection brackets as a list
# # the list pulls the specific columns identified
# employees.iloc[10:16, [3,4]]
#
# ```
#
# #### .loc
# You can use boolean indexing with the .loc operator to answer specific questions with your data. If you need to pull the employee numbers for everyone in the Sales department, you can do so easily with the syntax below.
#
# ```python
# # filters the rows where the Department is Sales and returns only the EmployeeNumber column
# employees.loc[employees.Department == 'Sales', 'EmployeeNumber']
#
# ```
# |    |   EmployeeNumber |
# |---:|-----------------:|
# |  0 |                1 |
# | 18 |               23 |
# | 21 |               27 |
# | 27 |               35 |
# | 29 |               38 |
#
#
# ```python
#
#
# # can use list notation to pull multiple columns
# employees.loc[employees.Department == 'Sales', ['EmployeeNumber','JobSatisfaction']]
#
# ```
#
#
# |    |   EmployeeNumber |   JobSatisfaction |
# |---:|-----------------:|------------------:|
# |  0 |                1 |                 4 |
# | 18 |               23 |                 4 |
# | 21 |               27 |                 1 |
# | 27 |               35 |                 2 |
# | 29 |               38 |                 1 |
#
# ``` python
# # can use the colon to pull a range of columns
# # the last value is included when using the colon notation with labels
# employees.loc[employees.Department == 'Sales', 'EmployeeNumber':'JobSatisfaction']
#
# ```
#
# |    |   EmployeeNumber |   EnvironmentSatisfaction | Gender   |   HourlyRate |   JobInvolvement |   JobLevel | JobRole              |   JobSatisfaction |
# |---:|-----------------:|--------------------------:|:---------|-------------:|-----------------:|-----------:|:---------------------|------------------:|
# |  0 |                1 |                         2 | Female   |           94 |                3 |          2 | Sales Executive      |                 4 |
# | 18 |               23 |                         1 | Female   |           78 |                2 |          4 | Manager              |                 4 |
# | 21 |               27 |                         3 | Male     |           82 |                2 |          1 | Sales Representative |                 1 |
# | 27 |               35 |                         3 | Male     |           48 |                3 |          2 | Sales Executive      |                 2 |
# | 29 |               38 |                         2 | Female   |           83 |                3 |          5 | Manager              |                 1 |
#
#
#
# #### .query
# Lastly we'll cover the query method which uses a string to filter DataFrame data.  It might feel a bit similar to a conditional formula in Excel. Let's run through some of our previous examples but using the query method.
#
# **Note:** If your column names have spaces they have to be wrapped in backticks i.e. `` `company code` ``
#
#
# ```python
# # returns employees in the Sales department
# # note that the conditional statement is in double quotes ("") any other strings referenced must use single quotes ('')
# employees.query("Department == 'Sales'")
#
#
# # you can use variables in conditional statement, but they must be preceded by an @ symbol when used in query statements
# dept = 'Sales'
# employees.query("Department == @dept")
#
#
# # returns Sales employees with JobSatisfaction >=3
# # when using .query() you can use and, or & not for logical operators
# employees.query("Department == 'Sales' and JobSatisfaction >= 3")
#
# ```

# %%
# returns the value in row 10 and column 2
employees.iloc[10, 2]
# Out:
# 'Travel_Rarely'

# %%
# returns the value in row 10 
# and the BusinessTravel column - column 2
employees.loc[10, 'BusinessTravel']
# Out:
# 'Travel_Rarely'

# %%
# returns rows 10 up to but not including 16
# and columns 2 up to but not including 5
employees.iloc[10:15:1, 2:5]
# Out:
#    BusinessTravel  DailyRate              Department
# 10  Travel_Rarely        809  Research & Development
# 11  Travel_Rarely        153  Research & Development
# 12  Travel_Rarely        670  Research & Development
# 13  Travel_Rarely       1346  Research & Development
# 14  Travel_Rarely        103  Research & Development

# %%
# returns rows 10 through 15
# and the BusinessTravel through the Department columns
# stop values are inclusive
employees.loc[10:15, 'BusinessTravel':'Department']
# Out:
#    BusinessTravel  DailyRate              Department
# 10  Travel_Rarely        809  Research & Development
# 11  Travel_Rarely        153  Research & Development
# 12  Travel_Rarely        670  Research & Development
# 13  Travel_Rarely       1346  Research & Development
# 14  Travel_Rarely        103  Research & Development
# 15  Travel_Rarely       1389  Research & Development

# %%
# the list pulls the specific rows and columns 
employees.iloc[[10,11,12,13,14,15], [2,3,4]]
# Out:
#    BusinessTravel  DailyRate              Department
# 10  Travel_Rarely        809  Research & Development
# 11  Travel_Rarely        153  Research & Development
# 12  Travel_Rarely        670  Research & Development
# 13  Travel_Rarely       1346  Research & Development
# 14  Travel_Rarely        103  Research & Development
# 15  Travel_Rarely       1389  Research & Development

# %%
# returns rows 10 through 15
# and the BusinessTravel through the Department columns
employees.loc[[10,11,12,13,14,15], 
              ['BusinessTravel','DailyRate','Department']]
# Out:
#    BusinessTravel  DailyRate              Department
# 10  Travel_Rarely        809  Research & Development
# 11  Travel_Rarely        153  Research & Development
# 12  Travel_Rarely        670  Research & Development
# 13  Travel_Rarely       1346  Research & Development
# 14  Travel_Rarely        103  Research & Development
# 15  Travel_Rarely       1389  Research & Development

# %%
employees.loc[employees.Department == 'Sales', 'EmployeeNumber':'JobSatisfaction':2]
# Out:
#       EmployeeNumber  Gender  JobInvolvement               JobRole
# 0                  1  Female               3       Sales Executive
# 18                23  Female               2               Manager
# 21                27    Male               2  Sales Representative
# 27                35    Male               3       Sales Executive
# 29                38  Female               3               Manager
# ...              ...     ...             ...                   ...
# 1454            2046  Female               3       Sales Executive
# 1461            2055    Male               2       Sales Executive
# 1462            2056  Female               2       Sales Executive
# 1464            2060  Female               2  Sales Representative
# 1468            2065    Male               2       Sales Executive
#
# [446 rows x 4 columns]

# %% [markdown]
# ## Data Cleaning
#
# There are a number of steps that you'll perform regularly when you clean data. Here are a few things that you'll regularly encounter and how to address them using pandas
#
# - renaming columns
# - dropping columns
# - type conversion
# - set_index
# - resetting index
# - check for duplicate values
# - sorting values

# %% [markdown]
# ### Renaming Columns and Indices
#
# Pandas DataFrames have a [rename method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html) that can be used to rename columns and indices.
#
# The third column in our dataset is called BusinessTravel. We can use the rename method and a Python dictionary to change the name to 'frequent_traveler'
#
# |    |   Age | Attrition   | BusinessTravel    |   DailyRate | Department             |
# |---:|------:|:------------|:------------------|------------:|:-----------------------|
# |  0 |    41 | Yes         | Travel_Rarely     |        1102 | Sales                  |
# |  1 |    49 | No          | Travel_Frequently |         279 | Research & Development |
#
# ##### Python Dictionary
# A Python dictionary is made up of key-value pairs wrapped in curly braces. It can be used to map values. Here we want to map the original column name BusinessTravel to the new column name frequent_traveler. In our example, we're only updating one column name, but your dictionary can contain more than one as long as each pair is separated by a comma.
#
# **Note**: If you include inplace = True as a parameter to the method you'll modify the original employees DataFrame otherwise you won't see your changes reflected. I typically don't use inplace operations and pass my changes to a new DataFrame
#
# ```python
# # dictionary example
# {'BusinessTravel':'frequent_traveler'}
#
# #renames the BusinessTravel column and modifies the original DataFrame
# employees.rename(columns = {'BusinessTravel':'frequent_traveler'},
#                  inplace = True)
#
# #renames the BusinessTravel column and returns a new DataFrame
# # the default parameter is inplace = False
# emps_cleaned_cols = employees.rename(columns = {'BusinessTravel':'frequent_traveler'})
#
# ```
#
# |    |   Age | Attrition   | frequent_traveler   |   DailyRate | Department             |
# |---:|------:|:------------|:--------------------|------------:|:-----------------------|
# |  0 |    41 | Yes         | Travel_Rarely       |        1102 | Sales                  |
# |  1 |    49 | No          | Travel_Frequently   |         279 | Research & Development |
#
#
# Alternatively you can replace all column names by updating the DataFrame's columns attribute.
# **Note:** This method can only be used when replacing ALL column names
#
#
# ```python
#
# new_cols = ['age', 'attrition', 'frequent_traveler', 'daily_rate', 'department',
#        'commute_distance', 'education', 'education_field', 'employee_count',
#        'employee_number', 'environment_satisfaction', 'gender', 'hourly_rate',
#        'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
#        'marital_status', 'monthly_income', 'monthly_rate', 'num_companies_worked',
#        'over_18', 'over_time', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'tenure', 'time_in_role', 'years_since_last_promotion',
#        'years_with_current_manager']
#
# employees.columns = new_cols
#
#
# ```
#
#
# We can use a similar syntax to rename an index value.
#
#
# ```python
#
# # renames the 0 index to 9999 and modifies the existing DataFrame
# employees.rename(index = {0:9999},
#                  inplace = True)
#
#
# ```
# |      |   age | attrition   | frequent_traveler   |   daily_rate | department             |
# |-----:|------:|:------------|:--------------------|------------:|:-----------------------|
# | 9999 |    41 | Yes         | Travel_Rarely       |        1102 | Sales                  |
# |    1 |    49 | No          | Travel_Frequently   |         279 | Research & Development |

# %%
# dictionary example
{'BusinessTravel':'frequent_traveler'}
# Out:
# {'BusinessTravel': 'frequent_traveler'}

# %%
#renames the BusinessTravel column as frequent_traveler
employees.rename(columns = {'BusinessTravel':'frequent_traveler'})
# Out:
#       Age Attrition  frequent_traveler  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
new_cols = ['age', 'attrition', 'frequent_traveler', 'daily_rate', 
            'department', 'commute_distance', 'education', 
            'education_field', 'employee_count','employee_number',
            'environment_satisfaction', 'gender', 'hourly_rate',
            'job_involvement', 'job_level', 'job_role', 
            'job_satisfaction', 'marital_status', 'monthly_income', 
            'monthly_rate', 'num_companies_worked','over_18', 
            'over_time', 'percent_salary_hike', 'performance_rating',
            'relationship_satisfaction', 'standard_hours', 
            'stock_option_level','total_working_years', 
            'training_times_last_year', 'work_life_balance',
            'tenure', 'time_in_role', 'years_since_last_promotion',
            'years_with_current_manager']

# %%
# replace all column names using the new_cols list
employees.columns = new_cols

# %%
# renames the 0 index to 9999 and modifies the existing DataFrame
employees.rename(index = {0:9999}, inplace = True)

# %% [markdown]
# ### Modifying the Index
#
# You can also modify the index by replacing it with the values from a column. The employee number field is made up of unique values so that's a good candidate, but keep in mind you can pass any list of values. This function removes employee number as a column and turns it into the index. For this example we're going to modify our DataFrame inplace
#
# ```python
# # uses employee number column as index
# employees.set_index('employee_number', inplace=True)
# ```
#
#
# |   employee_number |   age | attrition   | frequent_traveler   |   daily_rate | department             |
# |------------------:|------:|:------------|:--------------------|-------------:|:-----------------------|
# |                 1 |    41 | Yes         | Travel_Rarely       |         1102 | Sales                  |
# |                 2 |    49 | No          | Travel_Frequently   |          279 | Research & Development |
#
# The reset_index() method resets the index to a numeric list and moves the original index to a column in the DataFrame
#
# ```python
# # resets index to a numeric value and moves the original index to a column in the DataFrame
# employees.reset_index(inplace = True)
#
# ```
# |    |   employee_number |   age | attrition   | frequent_traveler   |   daily_rate |
# |---:|------------------:|------:|:------------|:--------------------|-------------:|
# |  0 |                 1 |    41 | Yes         | Travel_Rarely       |         1102 |
# |  1 |                 2 |    49 | No          | Travel_Frequently   |          279 |

# %%
# uses employee number column as index
employees.set_index('employee_number', inplace = True)

# %%
# resets index to a numeric value 
# and moves the original index to a column in the DataFrame
employees = employees.reset_index()

# %% [markdown]
# ### Finding and Removing Duplicate Values
#
# Duplicate values can make their way into datasets through both human or systems error. Let's use the example DataFrame below that has a list of employees, their names, and date of PTO taken. There are a few records with duplicate IDs and one where the entire row is duplicated. Pandas makes it easy to find duplicate values using the .duplicated() method.
#
# |    |   id | name          | pto_date        |
# |---:|-----:|:--------------|:--------------------|
# |  0 |    1 | Johan James   | 2021-01-02 00:00:00 |
# |  1 |    1 | Johan James   | 2021-01-15 00:00:00 |
# |  2 |    2 | Patty Smythe  | 2021-03-05 00:00:00 |
# |  3 |    2 | Patty Smythe  | 2021-04-11 00:00:00 |
# |  4 |    3 | Amanda Apple  | 2021-07-09 00:00:00 |
# |  5 |    4 | Arnold Jones  | 2021-10-11 00:00:00 |
# |  6 |    5 | Paul Nicholas | 2021-11-15 00:00:00 |
# |  7 |    6 | Ira Albert    | 2021-12-01 00:00:00 |
# |  8 |    6 | Ira Albert    | 2021-12-01 00:00:00 |
#
#
# #### Finding Duplicates
#
# ``` python
# # finds duplicates based on the id column
# # using keep = False returns all records
# # can use keep = 'first' or 'last' to return either the first or last record
#
# #passing this to the bracket notation returns the details for those rows
# pto[pto.duplicated(subset='id', keep = False)]
#
#
# ```
#
# |    |   id | name         | sign_in_date        |
# |---:|-----:|:-------------|:--------------------|
# |  0 |    1 | Johan James  | 2021-01-02 00:00:00 |
# |  1 |    1 | Johan James  | 2021-01-15 00:00:00 |
# |  2 |    2 | Patty Smythe | 2021-03-05 00:00:00 |
# |  3 |    2 | Patty Smythe | 2021-04-11 00:00:00 |
#
#
# ```python
# # finds duplicate rows - all details must match another row
#
# pto[pto.duplicated(keep = False)]
#
#
# ```
# |    |   id | name       | pto_date            |
# |---:|-----:|:-----------|:--------------------|
# |  7 |    6 | Ira Albert | 2021-12-01 00:00:00 |
# |  8 |    6 | Ira Albert | 2021-12-01 00:00:00 |
#
#
# #### Drop Duplicates

# %%
# creates new DataFrame of employee paid time off (PTO)


from datetime import datetime
pto = pd.DataFrame({'id':[1,1,2,2,3,4,5,6,6],
                    'name':['Johan James','Johan James','Patty Smythe','Patty Smythe',
                            'Amanda Apple','Arnold Jones','Paul Nicholas','Ira Albert','Ira Albert'],
                   'pto_date':[datetime(2021,1,2), datetime(2021,1,15),datetime(2021, 3,5),
                               datetime(2021,4,11),datetime(2021,7,9),datetime(2021,10,11), datetime(2021,11,15),datetime(2021,12,1),datetime(2021,12,1)]})
pto
# Out:
#    id           name   pto_date
# 0   1    Johan James 2021-01-02
# 1   1    Johan James 2021-01-15
# 2   2   Patty Smythe 2021-03-05
# 3   2   Patty Smythe 2021-04-11
# 4   3   Amanda Apple 2021-07-09
# 5   4   Arnold Jones 2021-10-11
# 6   5  Paul Nicholas 2021-11-15
# 7   6     Ira Albert 2021-12-01
# 8   6     Ira Albert 2021-12-01

# %%
# finds duplicates based on the id column
# using keep = False returns all records
# can use keep = 'first' or 'last' to return either the first or last record

#passing this to the bracket notation returns the details for those rows
pto[pto.duplicated(subset='id', keep = False)]
# Out:
#    id          name   pto_date
# 0   1   Johan James 2021-01-02
# 1   1   Johan James 2021-01-15
# 2   2  Patty Smythe 2021-03-05
# 3   2  Patty Smythe 2021-04-11
# 7   6    Ira Albert 2021-12-01
# 8   6    Ira Albert 2021-12-01

# %%
# drops duplicates based on id
# keeps the first value by default
pto.drop_duplicates(subset='id')
# Out:
#    id           name   pto_date
# 0   1    Johan James 2021-01-02
# 2   2   Patty Smythe 2021-03-05
# 4   3   Amanda Apple 2021-07-09
# 5   4   Arnold Jones 2021-10-11
# 6   5  Paul Nicholas 2021-11-15
# 7   6     Ira Albert 2021-12-01

# %%
# returns rows that are duplicated
pto[pto.duplicated(keep = False)]
# Out:
#    id        name   pto_date
# 7   6  Ira Albert 2021-12-01
# 8   6  Ira Albert 2021-12-01

# %%
# drops duplicate rows
pto.drop_duplicates()
# Out:
#    id           name   pto_date
# 0   1    Johan James 2021-01-02
# 1   1    Johan James 2021-01-15
# 2   2   Patty Smythe 2021-03-05
# 3   2   Patty Smythe 2021-04-11
# 4   3   Amanda Apple 2021-07-09
# 5   4   Arnold Jones 2021-10-11
# 6   5  Paul Nicholas 2021-11-15
# 7   6     Ira Albert 2021-12-01

# %% [markdown]
# ### Sorting Values
#
# We can use the sort_values() method to reorder the values of our DataFrame.  By default it will sort them in ascending order.
#
# To sort them in descending order, you'll pass the parameter ascending = False to the method.
#
#
# ```python
# # sorts the employee DataFrame by the department columns in descending order
# employees.sort_values(by='department', ascending = False)
#
# ```
#
# |      |   employee_number |   age | attrition   | frequent_traveler   |   daily_rate | department   |   commute_distance |
# |-----:|------------------:|------:|:------------|:--------------------|-------------:|:-------------|-------------------:|
# |    0 |                 1 |    41 | Yes         | Travel_Rarely       |         1102 | Sales        |                  1 |
# | 1102 |              1556 |    36 | No          | Travel_Rarely       |         1157 | Sales        |                  2 |
# |  467 |               626 |    37 | No          | Non-Travel          |          142 | Sales        |                  9 |
# | 1120 |              1583 |    38 | No          | Travel_Rarely       |          437 | Sales        |                 16 |
# |  469 |               631 |    32 | Yes         | Non-Travel          |         1474 | Sales        |                 11 |

# %%
# sorts the DataFrame by the department columns in ascending order
employees.sort_values(by='department')
# Out:
#       employee_number  age attrition  frequent_traveler  daily_rate  \
# 1035             1461   31        No      Travel_Rarely        1398
# 1096             1550   40        No      Travel_Rarely         898
# 1107             1563   38        No  Travel_Frequently         888
# 232               321   59        No      Travel_Rarely         818
# 1154             1625   47        No      Travel_Rarely        1176
# ...               ...  ...       ...                ...         ...
# 975              1372   55       Yes      Travel_Rarely         267
# 347               467   47        No  Travel_Frequently        1309
# 980              1379   31       Yes  Travel_Frequently         703
# 343               463   29        No      Travel_Rarely         144
# 0                   1   41       Yes      Travel_Rarely        1102
#
#            department  commute_distance  education  education_field  \
# 1035  Human Resources                 8          2          Medical
# ...

# %%
# sorting the DataFrame by the department columns in descending order
employees.sort_values(by='department', ascending = False)
# Out:
#       employee_number  age attrition  frequent_traveler  daily_rate  \
# 0                   1   41       Yes      Travel_Rarely        1102
# 1102             1556   36        No      Travel_Rarely        1157
# 467               626   37        No         Non-Travel         142
# 1120             1583   38        No      Travel_Rarely         437
# 469               631   32       Yes         Non-Travel        1474
# ...               ...  ...       ...                ...         ...
# 1107             1563   38        No  Travel_Frequently         888
# 789              1098   44       Yes      Travel_Rarely        1376
# 1379             1944   27       Yes  Travel_Frequently        1337
# 1269             1778   43        No      Travel_Rarely         244
# 1289             1805   38        No         Non-Travel        1336
#
#            department  commute_distance  education  education_field  \
# 0               Sales                 1          2    Life Sciences
# ...

# %%
# changes the employee number to a string
employees.employee_number.astype('str')
# Out:
# 0          1
# 1          2
# 2          4
# 3          5
# 4          7
#         ...
# 1465    2061
# 1466    2062
# 1467    2064
# 1468    2065
# 1469    2068
# Name: employee_number, Length: 1470, dtype: object

# %%
# save the change to the existing column
employees['employee_number'] = employees.employee_number.astype('str')

# %%
# save the change to a new column
employees['employee_number_str'] = employees.employee_number.astype('str')

# %%
# removes the first column - age
# removes row index 1
employees.drop(columns = 'age', index= 1)
# Out:
#      employee_number attrition  frequent_traveler  daily_rate  \
# 0                  1       Yes      Travel_Rarely        1102
# 2                  4       Yes      Travel_Rarely        1373
# 3                  5        No  Travel_Frequently        1392
# 4                  7        No      Travel_Rarely         591
# 5                  8        No  Travel_Frequently        1005
# ...              ...       ...                ...         ...
# 1465            2061        No  Travel_Frequently         884
# 1466            2062        No      Travel_Rarely         613
# 1467            2064        No      Travel_Rarely         155
# 1468            2065        No  Travel_Frequently        1023
# 1469            2068        No      Travel_Rarely         628
#
#                   department  commute_distance  education education_field  \
# 0                      Sales                 1          2   Life Sciences
# ...

# %%
# removes the columns - age and frequent traveler
# removes row indices 1 and 3
employees.drop(columns = ['age', 'frequent_traveler'], index= [1,3])
# Out:
#      employee_number attrition  daily_rate              department  \
# 0                  1       Yes        1102                   Sales
# 2                  4       Yes        1373  Research & Development
# 4                  7        No         591  Research & Development
# 5                  8        No        1005  Research & Development
# 6                 10        No        1324  Research & Development
# ...              ...       ...         ...                     ...
# 1465            2061        No         884  Research & Development
# 1466            2062        No         613  Research & Development
# 1467            2064        No         155  Research & Development
# 1468            2065        No        1023                   Sales
# 1469            2068        No         628  Research & Development
#
#       commute_distance  education education_field  employee_count  \
# 0                    1          2   Life Sciences               1
# ...

# %% [markdown]
# # Reshaping Data
# There are several options for reshaping data using pandas - two of the most common are pivot tables and crosstabs.
#
# ## Pivot Tables
# pandas enables you to create Excel style pivot tables using the pivot_table() method.  The key parameters that you want to use are the index/columns, the values and aggregating function or aggfunc. The mean will be used if no aggfunc is passed to the method. You can also include the grand totals in the pivot table by passing margins = True as a parameter. The downside to the pivot table is that you can't calculate row or column percentages directly in the table
#
#
# ```python
# # calculates the median salary by gender and attrition status
# employees.pivot_table(index= 'attrition',
#                       columns = 'gender',
#                       values='daily_rate',
#                       aggfunc = 'median')
#
# ```
#
# | attrition   |   Female |   Male |
# |:------------|---------:|-------:|
# | No          |      853 |    793 |
# | Yes         |      667 |    724 |
#
#
#
# ## Crosstabs
# Crosstabs are similar to pivot_tables except you use the pd.crosstab() method to create them. You pass the series for the index, columns and values to the method directly. Below is how you would calcuate the median daily rate by gender and attrition status using a crosstab.  The output is exactly the same as the table created using the pivot_table method()
#
# ```python
# #crosstab of median daily rate by attrition by gender
# pd.crosstab(employees.attrition, employees.gender, employees.daily_rate, aggfunc = 'median')
#
# ```
# | attrition   |   Female |   Male |
# |:------------|---------:|-------:|
# | No          |      853 |    793 |
# | Yes         |      667 |    724 |
#
# Unlike the pivot_table you can calculate the row and column percentages by using the parameter normalize = index or columns.
#
# The code to calculate the percent by row is below
#
# ```python
# # percent of median daily rate by row
# pd.crosstab(employees.attrition, employees.gender, employees.daily_rate, aggfunc = 'median', normalize = 'index')
#
#
# ```
#
#
# | attrition   |   Female |     Male |
# |:------------|---------:|---------:|
# | No          | 0.518226 | 0.481774 |
# | Yes         | 0.479511 | 0.520489 |
#
#
#
# ```python
# # percent of median daily rate by column
# pd.crosstab(employees.attrition, employees.gender, employees.daily_rate, aggfunc = 'median', normalize = 'columns')
#
# ```
#
# | attrition   |   Female |     Male |
# |:------------|---------:|---------:|
# | No          | 0.561184 | 0.522742 |
# | Yes         | 0.438816 | 0.477258 |

# %%
# calculates the median salary by gender and attrition status
employees.pivot_table(index= 'attrition', 
                      columns = 'gender', 
                      values='daily_rate', 
                      aggfunc = 'median')
# Out:
# gender     Female  Male
# attrition
# No            853   793
# Yes           667   724

# %%
# calculates the median salary by gender and attrition status
# using the margins parameter adds the totals
# by default the margin column name is All
# this can be updated using the margins_name parameter
employees.pivot_table(index= 'attrition', 
                      columns = 'gender', 
                      values='daily_rate', 
                      aggfunc = 'median',
                     margins=True,
                     margins_name='Total')
# Out:
# gender     Female  Male  Total
# attrition
# No          853.0   793  817.0
# Yes         667.0   724  699.0
# Total       825.5   783  802.0

# %%
# calculates the median salary by department, gender and attrition status
employees.pivot_table(index= ['department','attrition'], 
                      columns = 'gender', 
                      values='daily_rate', 
                      aggfunc = 'median')
# Out:
# gender                            Female   Male
# department             attrition
# Human Resources        No         1129.0  648.0
#                        Yes         954.0  424.0
# Research & Development No          820.0  825.0
#                        Yes         654.0  711.0
# Sales                  No          896.0  746.0
#                        Yes         664.5  743.0

# %%
# calculates the min, max and median salary by gender and attrition status
employees.pivot_table(index= 'attrition', 
                      columns = 'gender', 
                      values='daily_rate', 
                      aggfunc = ['median', 'min','max'])
# Out:
#           median         min         max
# gender    Female Male Female Male Female  Male
# attrition
# No           853  793    102  105   1499  1498
# Yes          667  724    104  103   1485  1496

# %%
#crosstab of median daily rate by attrition by gender
pd.crosstab(index = employees.attrition,
            columns = employees.gender, 
            values = employees.daily_rate, 
            aggfunc = 'median')
# Out:
# gender     Female  Male
# attrition
# No            853   793
# Yes           667   724

# %%
# percent of median daily rate by row
pd.crosstab(index = employees.attrition,
            columns = employees.gender, 
            values = employees.daily_rate, 
            aggfunc = 'median',
           normalize = 'index')
# Out:
# gender       Female      Male
# attrition
# No         0.518226  0.481774
# Yes        0.479511  0.520489

# %%
# percent of median daily rate by column
pd.crosstab(index  = employees.attrition, 
            columns = employees.gender, 
            values = employees.daily_rate, 
            aggfunc = 'median', 
            normalize = 'columns')
# Out:
# gender       Female      Male
# attrition
# No         0.561184  0.522742
# Yes        0.438816  0.477258

# %% [markdown]
# # Exploratory Data Analysis
#
# We've covered creating, exploring, and manipulating pandas DataFrames.  It's time to visualize our data! Since we're working with attrition data, let's start by taking a look at the percentage of employees in the file who have exited the organization. We can use the value_counts() method to calculate that for us.  We can either use method chaining to create our counts and the visualization or we can save the output of the value_counts() method to a new variable and use that.  Let's take a look at both options.

# %% [markdown]
# ## Creating a Chart Using Method Chaining

# %%
# Count of employees by status
employees.attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: attrition, dtype: int64

# %%
# chains the value_counts() method with the plot.pie() method to produce a pie chart
# autopct adds the percentage labels to the pie chart without using normalize
# the colors parameter updates the colors in the order that they appear in the series returned by the value_counts() method
employees.attrition.value_counts().plot.pie(title = 'Percent of Employees by Status', 
                                            colors = ['lightgray','orange'],
                                            autopct= '%.0f%%')
# Out:
# <AxesSubplot:title={'center':'Percent of Employees by Status'}, ylabel='attrition'>

# %% [markdown]
# ## Creating a Chart Using a Variable

# %%
# passing the series returned by the value_counts() method to a new variable called series
status_count = employees.attrition.value_counts()

# uses the status_count variable to create the pie chart
status_count.plot.pie(title = 'Percent of Employees by Status', 
                      colors = ['lightgray','orange'],
                      autopct= '%.0f%%')
# Out:
# <AxesSubplot:title={'center':'Percent of Employees by Status'}, ylabel='attrition'>

# %% [markdown]
# ## Exercise 1
#
# 1. Use the value_counts() method to get the count of employees by department
# 2. Visualize the counts as a pie chart by saving it to a new variable
# 3. Title your pie chart
# 4. Label your pie chart with percents
# 5. Update the colors of the pie chart
# TIP: You can find a list of the named colors [here](https://matplotlib.org/3.5.0/gallery/color/named_colors.html)

# %%
# save series returned by the value_counts of the department to a new variable
# dept_count = 

# visualize the new variable as a pie chart and update the parameters
# dept_count.plot.pie()

# %% [markdown]
# ## Attrition by Department
#
# If we wanted to calculate attrition by department, pie charts aren't going to be the best choice for comparing data.  Honestly, I'm not a big fan of pie charts in general.  Let's create a stacked bar chart to compare the attrition rates by department. We'll start by creating a crosstab since we can easily calculate the percentages and we'll save it as a new variable called attr_by_dept_pct

# %%
# creates a crosstab of attrition rates by departments
# includes a total attrition for the company
attr_by_dept_pct = pd.crosstab(index = employees.department, 
            columns= employees.attrition, normalize='index', 
                               margins= True, margins_name='Company')                               
                              

attr_by_dept_pct
# Out:
# attrition                     No       Yes
# department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278
# Company                 0.838776  0.161224

# %%
# plots the attrition by department
# uses a dictionary to map the name of the column to the color
attr_by_dept_pct.plot.barh(title = 'Attrition by Department', 
                           color = {'No':'lightgray', 'Yes':'orange'})
# Out:
# <AxesSubplot:title={'center':'Attrition by Department'}, ylabel='department'>

# %% [markdown]
# ## Attrition by Gender
# We would follow the same process to calculate and visualize attrition by Gender. Here we'll save our crosstab to a new variable called attr_by_gender_pct

# %%
# creates a crosstab of attrition rates by gender
# includes a total attrition for the company
attr_by_gender_pct = pd.crosstab(index = employees.gender, 
            columns= employees.attrition, normalize='index', 
                               margins= True, margins_name='Company')                               
                              

attr_by_gender_pct
# Out:
# attrition        No       Yes
# gender
# Female     0.852041  0.147959
# Male       0.829932  0.170068
# Company    0.838776  0.161224

# %%
# plots the attrition by gender
# uses a dictionary to map the name of the column to the color
attr_by_gender_pct.plot.barh(title = 'Attrition by Gender', 
                           color = {'No':'lightgray', 'Yes':'orange'})
# Out:
# <AxesSubplot:title={'center':'Attrition by Gender'}, ylabel='gender'>

# %% [markdown]
# ## Attrition in the Sales Department
#
# We can see from the charts above that attrition in the Sales Department is 21%.  We can create a separate DataFrame of just Sales employees to take a closer look at what's happening there. We can use the query method to filter our employees DataFrame to only reflect Sales employees. We're going to save this to a new variable called sales.
#
# You'll notice here I chained the copy() method onto my query method.  With a pandas any changes made to a subset of a DataFrame are also made to the original DataFrame. This means that if I don't use the copy method, any changes I make to the Sales DataFrame will also be reflected in the original Employees DataFrame.

# %%
# creates a DataFrame of the sales department
sales = employees.query("department == 'Sales'").copy()

# %% [markdown]
# ## Distribution of Monthly Income of Sales Employees
#
# I need to select the monthly income column from the sales DataFrame to plot the distribution. Here, I will use dot notation to select the column and I will chain plot.hist() to produce a histogram.

# %%
# plots a histogram of monthly income of the Sales department
sales.monthly_income.plot.hist()

#calculates median monthly_income of the Sales department
sales.monthly_income.median()
# Out:
# 5754.5

# %% [markdown]
# ## Distribution of Monthly Income of Sales Employees by Attrition Status
# If we want to compare the distribution of the monthly income of Sales employees, we would need to use a box plot. Unlike the other plotting methods, boxplot is called directly on the DataFrame.

# %%
# creates a horizontal boxplot of monthly income by attrition status
sales.boxplot(column= 'monthly_income', 
              by = 'attrition', 
              vert = False, # creates a horizontal box plot
              figsize = (7,5)) # adjusts the size of the figure
# Out:
# <AxesSubplot:title={'center':'monthly_income'}, xlabel='attrition'>

# %%
# creates a vertical boxplot of monthly income by attrition status
sales.boxplot(column= 'monthly_income', 
              by = 'attrition', 
              figsize = (5,7)) # adjusts the size of the figure
# Out:
# <AxesSubplot:title={'center':'monthly_income'}, xlabel='attrition'>

# %% [markdown]
# ## Exercise 2a
#
# 1. Use the boxplot() method to create a horizontal box plot of the years_since_last_promotion by attrition status
# 2. Title your box plot
# 3. Adjust the figsize parameter if you need more room

# %%
# create a horizontal box plot of years_since_last_promotion by attrition status
# use the parameter vert = False to make it horizontal

# %% [markdown]
# ## Exercise 2b
# 1. Use the boxplot() method to create a vertical box plot of the years_since_last_promotion by attrition status
# 2. Title your box plot
# 3. Adjust the figsize parameter if you need more room

# %%
# create a vertical box plot of years_since_last_promotion by attrition status
# use the parameter vert = False to make it horizontal

# %% [markdown]
# ## Compare Median Monthly Income by Attrition Status
# Box plots are good for showing the distribution of data, but we can use a bar plot to compare the median monthly income for Sales employees based on their attrition status.

# %%
# uses a pivot table to calculate the median monthly rate by attrition status in Sales
sales.pivot_table(index= 'attrition', 
                      values='monthly_income', 
                      aggfunc = 'median')
# Out:
#            monthly_income
# attrition
# No                 6073.5
# Yes                5314.0

# %%
# plots the median monthly income by attrition status
sales.pivot_table(index= 'attrition', 
                      values='monthly_income', 
                      aggfunc = 'median').plot.bar(title = 'Median Monthly Income by Attrition Status',
                                                   color= 'purple',
                                                   rot = 0)
# Out:
# <AxesSubplot:title={'center':'Median Monthly Income by Attrition Status'}, xlabel='attrition'>

# %% [markdown]
# ## Calculate Attrition by OT Status
# Our sales department data shows that 29% of employees work over time.  Let's see if that has an impact on attrition status.  This time, let's create a stacked bar chart to show the difference in rates.

# %%
# percent of employees working OT
sales.over_time.value_counts(normalize=True)
# Out:
# No     0.713004
# Yes    0.286996
# Name: over_time, dtype: float64

# %%
# creates a crosstab of attrition status by OT status
attrition_by_ot = pd.crosstab(index = sales.over_time, 
                              columns = sales.attrition, 
                              normalize='index')


# let's rename the index labels from No and Yes to no_ot and ot
# And reorder the attrition column in descending order
# to have this change saved, you'll need to update the attrition_by_ot variable or save it as a new variable
attrition_by_ot = (attrition_by_ot.rename(index = {'No':'no_ot', 'Yes':'ot'}) # using the rename method to change the index
                   .sort_index(axis = 1, # using the sort index method to reorder the columns; axis = 1 refers to columns
                               ascending=False)) 

# alternatively you can save this change "inplace"
# when you use inplace = True, you can't use method chaining
# pandas developers have said they're planning on getting rid of the function at some point
# attrition_by_ot = attrition_by_ot.rename(index = {'No':'no_ot', 'Yes':'ot'}, inplace = True)

# %%
#creates a chart of attrition rates based on OT status
attrition_by_ot.plot.barh(title = 'Attrition by OT Status',
                          color = {'No':'lightgray', 'Yes':'orange'},
                          stacked = True)# creates a 100% stacked bar chart
# Out:
# <AxesSubplot:title={'center':'Attrition by OT Status'}, ylabel='over_time'>

# %% [markdown]
# ## Exercise 3
# 1. Create a crosstab with the pct of job_role by attrition status with job_role in the index and save it to a variable called attrition_by_role
# 2. Plot a stacked horizontal bar chart
# 3. Add a title to your chart and update the colors so No is lightgray and Yes is orange

# %%
# creates crosstab of attrition by role
# attrition_by_role = 


# stacked bar chart of attrition by job role
# attrition_by_role.plot.bar()
